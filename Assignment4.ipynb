# %% [markdown]
# # Did Snowfall and Rainfall Effect wheather of United States of America (1961 - 1990)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.use('seaborn-colorblind')

# %%
Snowfall = pd.read_csv('UNdata.csv')
Snowfall.head()
# Out:
#        Country or Territory                  Station Name  WMO Station Number  \
# 0  UNITED STATES OF AMERICA  BARROW/W. POST W. ROGERS, AK             70026.0
# 1  UNITED STATES OF AMERICA       KOTZEBUE/RALPH WIEN, AK             70133.0
# 2  UNITED STATES OF AMERICA              BETTLES/FIELD AK             70174.0
# 3  UNITED STATES OF AMERICA                      NOME, AK             70200.0
# 4  UNITED STATES OF AMERICA     BETHEL/BETHEL AIRPORT, AK             70219.0
#
#    National Station Id Number     Period  Element-Statistic Qualifier Code  \
# 0                    500546.0  1961-1990                               NaN
# 1                    505076.0  1961-1990                               NaN
# 2                    500761.0  1961-1990                               NaN
# 3                    506496.0  1961-1990                               NaN
# 4                    500754.0  1961-1990                               NaN
#
#   Statistic Description Unit   Jan  Jan Footnotes  ...   Oct  Oct Footnotes  \
# 0          Median Value   cm   4.3            NaN  ...  14.0            NaN
# 1          Median Value   cm  14.2            NaN  ...  15.2            NaN
# 2          Median Value   cm  26.4            NaN  ...  28.7            NaN
# 3          Median Value   cm  17.3            NaN  ...  10.4            NaN
# 4          Median Value   cm  14.2            NaN  ...   9.4            NaN
#
#     Nov  Nov Footnotes   Dec  Dec Footnotes  Annual  Annual Footnotes  \
# 0   6.6            NaN   5.1            NaN -9999.9               2.0
# 1  19.0            NaN  16.5            NaN -9999.9               2.0
# 2  27.4            NaN  36.3            NaN -9999.9               2.0
# 3  27.4            NaN  22.9            NaN -9999.9               2.0
# 4  18.8            NaN  17.3            NaN -9999.9               2.0
#
#    Annual NCDC Computed Value  Annual NCDC Computed Value Footnotes
# 0                     -9999.9                                   2.0
# 1                     -9999.9                                   2.0
# 2                     -9999.9                                   2.0
# 3                     -9999.9                                   2.0
# 4                     -9999.9                                   2.0
#
# [5 rows x 36 columns]

# %%
Temperature = pd.read_excel('Temp_1961_1990.xlsx',engine='openpyxl')
Temperature.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22344/3198901806.py in <module>
# ----> 1 Temperature = pd.read_excel('Temp_1961_1990.xlsx',engine='openpyxl')
#       2 Temperature.head()
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1231         self.storage_options = storage_options
#    1232
# -> 1233         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1234
#    1235     def __fspath__(self):
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     520         """
#     521         import_optional_dependency("openpyxl")
# --> 522         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     523
#     524     @property
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer, storage_options)
#     408         )
#     409         if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 410             self.handles = get_handle(
#     411                 filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     412             )
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# PermissionError: [Errno 13] Permission denied: 'Temp_1961_1990.xlsx'

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\kbala\appdata\local\programs\python\python310\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\kbala\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install excel
# Out:
# Collecting excel
#   Downloading excel-1.0.0.tar.gz (2.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Using legacy 'setup.py install' for excel, since package 'wheel' is not installed.
# Installing collected packages: xlrd, excel
#     Running setup.py install for excel: started
#     Running setup.py install for excel: finished with status 'done'
# Successfully installed excel-1.0.0 xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
Rainfall = pd.read_csv('Rain_1961_1990.csv')
Rainfall.head()
# Out:
#               pr,"\t"Year""   Month   Country   ISO3   ISO2"\t
# 0   44.441,1968,1,USA,,\t\t     NaN       NaN    NaN       NaN
# 1  31.4801,1968,2,USA,,\t\t     NaN       NaN    NaN       NaN
# 2  42.2608,1968,3,USA,,\t\t     NaN       NaN    NaN       NaN
# 3  49.2687,1968,4,USA,,\t\t     NaN       NaN    NaN       NaN
# 4   68.475,1968,5,USA,,\t\t     NaN       NaN    NaN       NaN

# %%
Jan = Snowfall['Jan'].mean()
Feb = Snowfall['Feb'].mean()
Mar = Snowfall['Mar'].mean()
Apr = Snowfall['Apr'].mean()
May = Snowfall['May'].mean()
Jun = Snowfall['Jun'].mean()
Jul = Snowfall['Jul'].mean()
Aug = Snowfall['Aug'].mean()
Sep = Snowfall['Sep'].mean()
Oct = Snowfall['Oct'].mean()
Nov = Snowfall['Nov'].mean()
Dec = Snowfall['Dec'].mean()

# %%
Weather = pd.DataFrame({'Snowfall': [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]})
Weather
# Out:
#         Snowfall
# 0   32910.929764
# 1   32099.560367
# 2   32814.367087
# 3   35263.127507
# 4   35805.531129
# 5   30106.764987
# 6   29014.876535
# 7   28906.219423
# 8   32462.127717
# 9   35576.560892
# 10  34939.955171
# 11  33215.316745

# %%
Monthly_Temp = Temperature.groupby(' Month').mean()['tas']
Jan = Monthly_Temp.iloc[0]
Feb = Monthly_Temp.iloc[1]
Mar = Monthly_Temp.iloc[2]
Apr = Monthly_Temp.iloc[3]
May = Monthly_Temp.iloc[4]
Jun = Monthly_Temp.iloc[5]
Jul = Monthly_Temp.iloc[6]
Aug = Monthly_Temp.iloc[7]
Sep = Monthly_Temp.iloc[8]
Oct = Monthly_Temp.iloc[9]
Nov = Monthly_Temp.iloc[10]
Dec = Monthly_Temp.iloc[11]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22344/2303750842.py in <module>
# ----> 1 Monthly_Temp = Temperature.groupby(' Month').mean()['tas']
#       2 Jan = Monthly_Temp.iloc[0]
#       3 Feb = Monthly_Temp.iloc[1]
#       4 Mar = Monthly_Temp.iloc[2]
#       5 Apr = Monthly_Temp.iloc[3]
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'tas'

# %%
Weather['Temperature'] = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
Weather

# %%
Monthly_Rain = Rainfall.groupby(' Month').mean()['pr']
Monthly_Rain.iloc[0]
Jan = Monthly_Rain.iloc[0]
Feb = Monthly_Rain.iloc[1]
Mar = Monthly_Rain.iloc[2]
Apr = Monthly_Rain.iloc[3]
May = Monthly_Rain.iloc[4]
Jun = Monthly_Rain.iloc[5]
Jul = Monthly_Rain.iloc[6]
Aug = Monthly_Rain.iloc[7]
Sep = Monthly_Rain.iloc[8]
Oct = Monthly_Rain.iloc[9]
Nov = Monthly_Rain.iloc[10]
Dec = Monthly_Rain.iloc[11]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22344/324030753.py in <module>
# ----> 1 Monthly_Rain = Rainfall.groupby(' Month').mean()['pr']
#       2 Monthly_Rain.iloc[0]
#       3 Jan = Monthly_Rain.iloc[0]
#       4 Feb = Monthly_Rain.iloc[1]
#       5 Mar = Monthly_Rain.iloc[2]
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'pr'

# %%
Weather['Rainfall'] = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
Weather

# %%
Weather['Snowfall'] = Weather['Snowfall']/1000
Weather

# %%
Weather.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Weather

# %%
x = Weather.index.tolist()
y1 = Weather['Snowfall'].tolist()
y2 = Weather['Temperature'].tolist()
y3 = Weather['Rainfall'].tolist()

plt.plot(x, y1, '-s', label = "Snowfall (in 0.1*m)")
plt.plot(x, y2, '-*', label = "Temperature (in $\,^{\circ}\mathrm{C}$)")
plt.plot(x, y3, '-o', label = "Rainfall (in 0.1*cm)")

plt.title('Average Temperature, Snowfall and Rainfall in United States(1961-1990)')
 
plt.legend(frameon=False)
[plt.gca().spines[loc].set_visible(False) for loc in ['top', 'right']]

plt.show()
